# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramanuja1148/Datascience/blob/main/raja1148.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# %%R
# x<-1:10
# y<-x^2
# plot(x,y)

# %%
# %%R
# x<-rep(c("ds","ai","iot","ml"),c(8,10,5,2))
# print(x)
# mytable <- table(x)
# print(mytable)
# barplot(mytable)
# Out:
#  [1] "ds"  "ds"  "ds"  "ds"  "ds"  "ds"  "ds"  "ds"  "ai"  "ai"  "ai"  "ai"
# [13] "ai"  "ai"  "ai"  "ai"  "ai"  "ai"  "iot" "iot" "iot" "iot" "iot" "ml"
# [25] "ml"
# x
#  ai  ds iot  ml
#  10   8   5   2

# %%
# %%R
# barplot(mytable,col=1:4,main="barplot",las=0)

# %%
# %%R
# x<-rep(c("ds","ai","iot","ml"),c(8,10,5,2))
# print(x)
# mytable <- table(x)
# pie(mytable,
#     main="the pie chart",
#     col=c("lightblue","lightgreen","salmon","maroon"))
# Out:
#  [1] "ds"  "ds"  "ds"  "ds"  "ds"  "ds"  "ds"  "ds"  "ai"  "ai"  "ai"  "ai"
# [13] "ai"  "ai"  "ai"  "ai"  "ai"  "ai"  "iot" "iot" "iot" "iot" "iot" "ml"
# [25] "ml"

# %%
# %%R
# x<-matrix(rnorm(1000),ncol=4)
# xdf=as.data.frame(x)
# print(xdf)
# boxplot(xdf)
# Out:
#                V1            V2           V3          V4
# 1    0.5529642260 -6.255571e-01  0.149613191 -0.49997792
# 2   -0.6191828547  8.708121e-01 -0.262992083  1.17416742
# 3    0.9397274437  7.494193e-01 -1.295292474  0.52817681
# 4   -0.6033338883 -3.686809e-02 -1.500268344 -0.63926981
# 5    1.3427157111 -1.035449e+00  1.263108813  1.83430093
# 6    0.6453150149  1.008563e+00 -1.136944533 -0.28784415
# 7   -1.6948859263  9.101828e-01  0.347217734  1.35220999
# 8    0.8361705123  1.313326e+00 -0.824598130  0.26320465
# 9    1.2019036570  8.600404e-01 -0.011845832  0.04451744
# 10  -0.1386119205 -1.217381e-01 -0.606080275  0.08902815
# 11  -0.6750712485  5.046712e-01 -1.025645249  0.31454120
# 12  -0.1183067393 -9.429409e-01  0.658872835 -0.81578551
# 13  -0.9907408738  7.218907e-01 -0.066371077 -1.37594524
# 14  -0.2968296775  1.331872e+00  1.637234390  0.77005270
# 15   1.0975766275  1.065908e-01 -0.284440126  0.32721168
# ...

# %%
# %%R
# x<-rnorm(200)
# hist(x)
# print(mean(x))
# print(sd(x))
# Out:
# [1] -0.08590559
# [1] 0.9835926

# %%
# %%R
# hist(x,
#      border="red",
#      breaks=50,
#      main="histogram",
#      xlab="",
#      cex.main=2.5,
#      cex.lab=2)

# %%
# %%R
# library(ggplot2)

# %%
# %%R
# data("iris")
# ggplot(data=iris,mapping=aes(x=Species,y=Sepal.Length))+geom_point()

# %%
# %%R
# data("iris")
# ggplot(data=iris,mapping=aes(x=Species,y=Sepal.Length))

# %%
# %%R
# ggplot(data=iris,mapping=aes(x=Sepal.Width,y=Sepal.Length))+geom_point()

# %%
# %%R
# ggplot(data=iris,mapping=aes(x=Sepal.Width,y=Sepal.Length))+geom_point(colour="red")

# %%
# %%R
# ggplot(data=iris,mapping=aes(x=Sepal.Width,y=Sepal.Length,colour=Species))+geom_point()

# %%
# %%R
# ggplot(data=iris,mapping=aes(x=Sepal.Width,y=Species,fill=Species))+
# geom_boxplot()

# %%
# %%R
# ggplot(data=iris,mapping=aes(x=Sepal.Length,fill=Species))+
# geom_bar()

# %%
# %%R
# ggplot(data=iris,mapping=aes(x=Sepal.Length,fill=Species))+
# geom_histogram()
# Out:
# R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
# %%R
# ggplot(data=iris,mapping=aes(x=Sepal.Length,fill=Species))+
# geom_histogram(position="dodge")
# Out:
# R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
# %%R
# library(readr)
# library(dplyr)
# library(tidyr)
# library(ggplot2)
# Out:
# R[write to console]:
# Attaching package: ‘dplyr’
#
#
# R[write to console]: The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# R[write to console]: The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
# %%R
# ga=read_csv("/content/GAdata.csv")
# Out:
# Rows: 500 Columns: 9
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (9): SerialNo., GREScore, TOEFLScore, UniversityRating, SOP, LOR, CGPA, ...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
# %%R
# ga
# Out:
# # A tibble: 500 × 9
#    SerialNo. GREScore TOEFLScore UniversityRating   SOP   LOR  CGPA Research
#        <dbl>    <dbl>      <dbl>            <dbl> <dbl> <dbl> <dbl>    <dbl>
#  1         1      337        118                4   4.5   4.5  9.65        1
#  2         2      324        107                4   4     4.5  8.87        1
#  3         3      316        104                3   3     3.5  8           1
#  4         4      322        110                3   3.5   2.5  8.67        1
#  5         5      314        103                2   2     3    8.21        0
#  6         6      330        115                5   4.5   3    9.34        1
#  7         7      321        109                3   3     4    8.2         1
#  8         8      308        101                2   3     4    7.9         0
#  9         9      302        102                1   2     1.5  8           0
# 10        10      323        108                3   3.5   3    8.6         0
# ...

# %%
# %%R
# ga1=select(ga,-"SerialNo.")
# print(ga1)
# Out:
# # A tibble: 500 × 8
#    GREScore TOEFLScore UniversityRating   SOP   LOR  CGPA Research ChanceofAdmit
#       <dbl>      <dbl>            <dbl> <dbl> <dbl> <dbl>    <dbl>         <dbl>
#  1      337        118                4   4.5   4.5  9.65        1          0.92
#  2      324        107                4   4     4.5  8.87        1          0.76
#  3      316        104                3   3     3.5  8           1          0.72
#  4      322        110                3   3.5   2.5  8.67        1          0.8
#  5      314        103                2   2     3    8.21        0          0.65
#  6      330        115                5   4.5   3    9.34        1          0.9
#  7      321        109                3   3     4    8.2         1          0.75
#  8      308        101                2   3     4    7.9         0          0.68
#  9      302        102                1   2     1.5  8           0          0.5
# ...

# %%
# %%R
# cor(ga1)
# Out:
#                   GREScore TOEFLScore UniversityRating       SOP       LOR
# GREScore         1.0000000  0.8272004        0.6353762 0.6134977 0.5246794
# TOEFLScore       0.8272004  1.0000000        0.6497992 0.6444104 0.5415633
# UniversityRating 0.6353762  0.6497992        1.0000000 0.7280236 0.6086507
# SOP              0.6134977  0.6444104        0.7280236 1.0000000 0.6637069
# LOR              0.5246794  0.5415633        0.6086507 0.6637069 1.0000000
# CGPA             0.8258780  0.8105735        0.7052543 0.7121543 0.6374692
# Research         0.5633981  0.4670121        0.4270475 0.4081158 0.3725256
# ChanceofAdmit    0.8103506  0.7922276        0.6901324 0.6841365 0.6453645
#                       CGPA  Research ChanceofAdmit
# GREScore         0.8258780 0.5633981     0.8103506
# TOEFLScore       0.8105735 0.4670121     0.7922276
# UniversityRating 0.7052543 0.4270475     0.6901324
# SOP              0.7121543 0.4081158     0.6841365
# ...

# %%
# %%R
# install.packages("corrplot")
# Out:
# R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/corrplot_0.92.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 3765850 bytes (3.6 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %%
# %%R
# library(corrplot)
# corrplot(cor(ga1),method="circle")

# %%
# %%R
# colnames(ga1)
# ga1$TOEFLScore
# Out:
#   [1] 118 107 104 110 103 115 109 101 102 108 106 111 112 109 104 105 107 106
#  [19] 110 102 107 114 116 119 119 120 109  98  93  99  97 103 118 114 112 110
#  [37] 106 105 105 108 110 105 107 117 113 110 114 119 110 111  98 100 116 112
#  [55] 110 103 102  99  99 104 100 101 105 107 111 112 114 107 109 115 118 112
#  [73] 111 108 106 114 112  99  95  93 105 120 110 115 115 103 106 107 108 109
#  [91] 106  97  98  97  99 100 100 120 119 113 107 105 106 104 112 110 111 117
# [109] 116 103 108 109 107 110 105 106 102 104  99 104 117 119 106 108 106 100
# [127] 113 112 112 118 114 105 105 112 113 109 103 100 116 109 110 118 115 120
# [145] 112 113 105 114 116 106 114 116 112 105 108 109 105 104 106 100 103  99
# [163] 109 105 111 110 102 102  97  99 101 117 110 113 111 111 119 110 108 102
# [181] 104 107 100 110 106 113 107 118 115 112 111 110 114 118 109 107 105 106
# [199] 104 107 103 110 120 120 105  99  99 102 106 104 108 110 120 119 117 116
# ...

# %%
# %%R
# #print(ga1$Chance_of_Admit)
# relation<-lm(ga1$ChanceofAdmit~(ga1$GREScore+ga1$TOEFLScore+ga1$CGPA))
# print(relation)
# Out:
# Call:
# lm(formula = ga1$ChanceofAdmit ~ (ga1$GREScore + ga1$TOEFLScore +
#     ga1$CGPA))
#
# Coefficients:
#    (Intercept)    ga1$GREScore  ga1$TOEFLScore        ga1$CGPA
#      -1.596809        0.002352        0.003199        0.143574

# %%
# %%R
# print(coefficients(relation))
# Out:
#    (Intercept)   ga1$GREScore ga1$TOEFLScore       ga1$CGPA
#   -1.596809348    0.002351948    0.003198647    0.143574061

# %%
# %%R
# str(relation)
# relation$coefficients[1]
# Out:
# List of 12
#  $ coefficients : Named num [1:4] -1.59681 0.00235 0.0032 0.14357
#   ..- attr(*, "names")= chr [1:4] "(Intercept)" "ga1$GREScore" "ga1$TOEFLScore" "ga1$CGPA"
#  $ residuals    : Named num [1:500] -0.038727 -0.020979 0.092342 0.042844 0.000094 ...
#   ..- attr(*, "names")= chr [1:500] "1" "2" "3" "4" ...
#  $ effects      : Named num [1:500] -16.1386 -2.5549 0.68401 1.0014 -0.00304 ...
#   ..- attr(*, "names")= chr [1:500] "(Intercept)" "ga1$GREScore" "ga1$TOEFLScore" "ga1$CGPA" ...
#  $ rank         : int 4
#  $ fitted.values: Named num [1:500] 0.959 0.781 0.628 0.757 0.65 ...
#   ..- attr(*, "names")= chr [1:500] "1" "2" "3" "4" ...
#  $ assign       : int [1:4] 0 1 2 3
#  $ qr           :List of 5
#   ..$ qr   : num [1:500, 1:4] -22.3607 0.0447 0.0447 0.0447 0.0447 ...
#   .. ..- attr(*, "dimnames")=List of 2
#   .. .. ..$ : chr [1:500] "1" "2" "3" "4" ...
#   .. .. ..$ : chr [1:4] "(Intercept)" "ga1$GREScore" "ga1$TOEFLScore" "ga1$CGPA"
# ...

# %%
# %%R
# c=relation$coefficients[1]
# m1=relation$coefficients[2]
# m2=relation$coefficients[3]
# m3=relation$coefficients[4]
# print(c)
# print(m1)
# print(m2)
# print(m3)
# Out:
# (Intercept)
#   -1.596809
# ga1$GREScore
#  0.002351948
# ga1$TOEFLScore
#    0.003198647
#  ga1$CGPA
# 0.1435741

# %%
# %%R
# ca=c+m1*338+m2*118+m3*9.8
# print(ca)
# Out:
# (Intercept)
#   0.9826152

# %%
# %%R
# colnames(ga2)
# ga3=select(ga2,ChanceofAdmit,predicted,difference)
# print(tbl_df(ga3),n=100)
# Out:
# # A tibble: 500 × 3
#     ChanceofAdmit predicted difference
#             <dbl>     <dbl>      <dbl>
#   1          0.92     0.959 -0.0387
#   2          0.76     0.781 -0.0210
#   3          0.72     0.628  0.0923
#   4          0.8      0.757  0.0428
#   5          0.65     0.650  0.0000940
#   6          0.9      0.888  0.0118
#   7          0.75     0.684  0.0659
#   8          0.68     0.585  0.0951
#   9          0.5      0.588 -0.0883
#  10          0.45     0.743 -0.293
#  11          0.52     0.713 -0.193
#  12          0.84     0.819  0.0205
#  13          0.78     0.839 -0.0594
#  14          0.62     0.622 -0.00248
#  15          0.61     0.645 -0.0346
#  16          0.54     0.669 -0.129
#  17          0.66     0.740 -0.0801
#  18          0.65     0.641  0.00889
#  19          0.63     0.766 -0.136
#  20          0.62     0.662 -0.0425
#  21          0.64     0.613  0.0265
#  22          0.7      0.738 -0.0382
#  23          0.94     0.910  0.0304
# ...

# %%
# %%R
# #print(ga1$Chance_of_Admit)
# relation<-lm(ga1$ChanceofAdmit~(ga1$GREScore+ga1$TOEFLScore+ga1$CGPA+ga1$SOP+ga1$UniversityRating))
# print(relation)
# Out:
# Call:
# lm(formula = ga1$ChanceofAdmit ~ (ga1$GREScore + ga1$TOEFLScore +
#     ga1$CGPA + ga1$SOP + ga1$UniversityRating))
#
# Coefficients:
#          (Intercept)          ga1$GREScore        ga1$TOEFLScore
#            -1.438603              0.002304              0.002603
#             ga1$CGPA               ga1$SOP  ga1$UniversityRating
#             0.127995              0.007779              0.009075

# %%
# %%R
# c=relation$coefficients[1]
# m1=relation$coefficients[2]
# m2=relation$coefficients[3]
# m3=relation$coefficients[4]
# m4=relation$coefficients[5]
# m5=relation$coefficients[6]
# print(c)
# print(m1)
# print(m2)
# print(m3)
# print(m4)
# print(m5)
# Out:
# (Intercept)
#   -1.438603
# ga1$GREScore
#    0.0023038
# ga1$TOEFLScore
#    0.002602854
#  ga1$CGPA
# 0.1279954
#     ga1$SOP
# 0.007778737
# ga1$UniversityRating
#          0.009074942

# %%
# %%R
# ca=c+m1*338+m2*118+m3*9.8+m4*5*m5*5
# print(ca)
# Out:
# (Intercept)
#   0.9033379
